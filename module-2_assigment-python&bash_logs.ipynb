# %%
print ("Hello World")
# Out:
# Hello World

# %%
name = "manish siwach"
print ("my name is:", name)
# Out:
# my name is: manish siwach

# %%
name = input ("please enter your name :")
print (name)
# Out:
# please enter your name : manni
# manni

# %%
num = int(input ("Enter a number:"))
if (num > 18):
    print ("you can take a part in club")

else:
    print ("you are too young to enter the club")
# Out:
# Enter a number: 35
# you can take a part in club

# %%
score = int(input("please enter your score:"))
name = input ("please enter your name")
if (score >= 90 ):
    print (name , 'your grade is "A"')
elif (score >= 80 ):
    print (name , 'your grade is "B"')
elif (score >= 70 ):
    print (name , 'your grade is "C"')
elif (score >= 60 ):
    print (name , 'your grade is "D"')

else:
    print (name , 'your grade is "F"')
# Out:
# please enter your score: 89
# please enter your name j
# j your grade is "B"

# %%
students = {
    "abhishek" : "C",
    "kapil" : "B"
}
print (students)
name = input ("please enter your name:")
grade = input ("please enter your grade:")
students [name] = grade
print (students)
students ["kapil"] = "A+"
print (students)
# Out:
# {'abhishek': 'C', 'kapil': 'B'}
# please enter your name: manish
# please enter your grade: A+
# {'abhishek': 'C', 'kapil': 'B', 'manish': 'A+'}
# {'abhishek': 'C', 'kapil': 'A+', 'manish': 'A+'}

# %%
file = open("python.txt", "w")

file.write("Hello, my name is manish, i m writing the content using python.\n")
file.write("I m a devops engineer.\n")

file.close()

# %%
file = open("python.txt", "r")

content = file.read()
print(content)

file.close()
# Out:
# Hello, my name is manish, i m writing the content using python.
# I m a devops engineer.
